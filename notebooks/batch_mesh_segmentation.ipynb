# %%
import subprocess, sys, shlex, textwrap

def run_batch_segmentation(
    split_dir         : str,
    config_path       : str,
    output_dir        : str,
    *,
    prefixes          = ("matte_", "segmented_"),
    resolution        = (2048, 2048),
    max_workers       = 8,
    clear_dir         = True,
    visualize         = False,
    batch_script_path = "batch_mesh_segmentation.py",  # 위치만 맞춰 주세요
):
    """
    Jupyter-friendly wrapper around batch_mesh_segmentation.py.
    Prints all stdout/stderr lines as they arrive.
    """
    cmd = [
        sys.executable, batch_script_path,
        "--split-dir",   split_dir,
        "--config",      config_path,
        "--output",      output_dir,
        "--prefixes",   *prefixes,
        "--resolution",  str(resolution[0]), str(resolution[1]),
        "--max-workers", str(max_workers),
    ]
    if clear_dir:
        cmd.append("--clear-dir")
    if visualize:
        cmd.append("--visualize")

    print("▶ Running:\n", textwrap.indent(shlex.join(cmd), "  "))

    proc = subprocess.Popen(
        cmd,
        stdout=subprocess.PIPE,
        stderr=subprocess.STDOUT,
        text=True,
        bufsize=1,                # line-buffered
    )

    try:
        for line in proc.stdout:
            print(line, end="")    # 이미 줄바꿈 포함
    except KeyboardInterrupt:
        print("\n⏹️  KeyboardInterrupt → terminating subprocess …")
        proc.terminate()
        proc.wait()

    if proc.returncode == 0:
        print("\n✅ batch finished successfully.")
    else:
        print(f"\n❌ batch exited with code {proc.returncode}.")

run_batch_segmentation(
    split_dir   = "../assets/CustomDataset_Completed/000-000",
    config_path = "../configs/mesh_segmentation.yaml",
    output_dir  = "../outputs/mesh_segmentation_output/CustomDataset/000-000",
    resolution  = (2048, 2048),
    max_workers = 1,          # CPU 상황 춰 조절
    clear_dir   = True,       # --clear-dir
    visualize   = True,      # --visualize
)
# Out:
# ▶ Running:
#    /home/user/anaconda3/envs/samesh/bin/python batch_mesh_segmentation.py --split-dir ../assets/CustomDataset_Completed/000-000 --config ../configs/mesh_segmentation.yaml --output ../outputs/mesh_segmentation_output/CustomDataset/000-000 --prefixes matte_ segmented_ --resolution 2048 2048 --max-workers 1 --clear-dir --visualize
# 387 meshes found in ../assets/CustomDataset_Completed/000-000
# ✅ 275f4cdac1494fb6b14a92b65181eee1 done
# ✅ 0ab41014322b468f901b2e3887f19688 done
# ❌ 234ea64c630a4a34af2e6d73c6a9fe6d failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/234ea64c630a4a34af2e6d73c6a9fe6d/234ea64c630a4a34af2e6d73c6a9fe6d.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/234ea64c630a4a34af2e6d73c6a9fe6d
#
# INFO | Segmenting mesh 234ea64c630a4a34af2e6d73c6a9fe6d.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.55it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  3.80it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:02,  4.19it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.39it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.51it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.20it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 260, in render_func
#     return render_multiview(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 223, in render_multiview
#     outputs = renderer.render(pose, lightdir=compute_lightdir(pose), **renderer_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 191, in render
#     matte = raw_color if uv_map else render_matte(norms, raw_depth, faces, bcent) # use original depth for matte
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 170, in render_matte
#     verts_index = self.tmesh.faces[faces.reshape(-1)]    # (n, 3)
#                   ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# IndexError: index 409 is out of bounds for axis 0 with size 404
#
# ✅ 04e7e58ee70c449982ff24519ccfdde5 done
# ✅ 015d02aa38e04950825ec5f8dc3d533d done
# ✅ 82776aa4669149a49e34ac86e6c34185 done
# ✅ 04949eda2fbc452e9159d088a994336b done
# ✅ 1a84fe08f05f4ee59283fff57ad1b97b done
# ✅ 7514b214acda44259d24687469b414dc done
# ✅ eb7714da430449b79385ab1de50fb5bb done
# ✅ 21d88413da6545cd9a3159ac346a5d1a done
# ✅ 34eaddd2c97340f191b4eb22c8614a89 done
# ✅ 567cb7974448493e871eaa6548aa3d80 done
# ✅ 0135eda69a2b4b71956f2ee1a3650fc6 done
# ✅ 03813fe8eab1417eb7bffb45f9f083b1 done
# ❌ a0739726481743da91f1173dcaf1ac6c failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/a0739726481743da91f1173dcaf1ac6c/a0739726481743da91f1173dcaf1ac6c.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/a0739726481743da91f1173dcaf1ac6c
#
# INFO | Segmenting mesh a0739726481743da91f1173dcaf1ac6c.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.05it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.11it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:02,  4.14it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.12it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.10it/s]
# Rendering Multiviews...:  50%|█████     | 6/12 [00:01<00:01,  4.13it/s]
# Rendering Multiviews...:  58%|█████▊    | 7/12 [00:01<00:01,  4.18it/s]
# Rendering Multiviews...:  67%|██████▋   | 8/12 [00:01<00:00,  4.17it/s]
# Rendering Multiviews...:  75%|███████▌  | 9/12 [00:02<00:00,  4.22it/s]
# Rendering Multiviews...:  83%|████████▎ | 10/12 [00:02<00:00,  4.24it/s]
# Rendering Multiviews...:  92%|█████████▏| 11/12 [00:02<00:00,  4.27it/s]
# Rendering Multiviews...: 100%|██████████| 12/12 [00:02<00:00,  4.29it/s]
# Rendering Multiviews...: 100%|██████████| 12/12 [00:02<00:00,  4.20it/s]
#
# Computing SAM Masks for norms: 0it [00:00, ?it/s]INFO | For numpy array image, we assume (HxWxC) format
# INFO | Computing image embeddings for the provided image...
# INFO | Image embeddings computed.
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory efficient kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:607.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory Efficient attention has been runtime disabled. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:495.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Flash attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:609.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Expected query, key and value to all be of dtype: {Half, BFloat16}. Got Query dtype: float, Key dtype: float, and Value dtype: float instead. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:98.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: CuDNN attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:611.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: The CuDNN backend needs to be enabled by setting the enviornment variable`TORCH_CUDNN_SDPA_ENABLED=1` (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:409.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py:1541: UserWarning: Flash Attention kernel failed due to: No available kernel. Aborting execution.
# Falling back to all available kernels for scaled_dot_product_attention (which may have a slower speed).
#   return forward_call(*args, **kwargs)
#
# Computing SAM Masks for norms: 1it [00:01,  1.94s/it]
# Computing SAM Masks for norms: 1it [00:01,  1.94s/it]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 293, in render
#     call_sam(image, faces != -1) for image, faces in \
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 285, in call_sam
#     [point_grid_from_mask(mask, self.config.sam.sam.engine_config.points_per_side ** 2)]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam.py", line 105, in point_grid_from_mask
#     raise ValueError('No valid points in mask')
# ValueError: No valid points in mask
#
# ✅ 871dce7c7d7a4da893fce4710aa3984e done
# ✅ 04eeb41058c64a039ce777800cd22580 done
# ❌ deb1dc948d13494cb0a83a7261b038c1 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/deb1dc948d13494cb0a83a7261b038c1/deb1dc948d13494cb0a83a7261b038c1.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/deb1dc948d13494cb0a83a7261b038c1
#
# INFO | Segmenting mesh deb1dc948d13494cb0a83a7261b038c1.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.39it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.70it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:01,  4.78it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:02,  4.48it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 260, in render_func
#     return render_multiview(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 223, in render_multiview
#     outputs = renderer.render(pose, lightdir=compute_lightdir(pose), **renderer_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 191, in render
#     matte = raw_color if uv_map else render_matte(norms, raw_depth, faces, bcent) # use original depth for matte
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 170, in render_matte
#     verts_index = self.tmesh.faces[faces.reshape(-1)]    # (n, 3)
#                   ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# IndexError: index 8355791 is out of bounds for axis 0 with size 184
#
# ✅ 3f428847eafc407dada5b073e53ebd0d done
# ✅ 008fda58985040279284e7498dd30c49 done
# ✅ 1557fd3289104918ab475b8e1e6c7063 done
# ✅ 89966ab7901f40c1bd522ec75ef46549 done
# ❌ 02ff51f84324460cb826bf2a618358bc failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/02ff51f84324460cb826bf2a618358bc/02ff51f84324460cb826bf2a618358bc.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/02ff51f84324460cb826bf2a618358bc
#
# INFO | Segmenting mesh 02ff51f84324460cb826bf2a618358bc.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  3.96it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.48it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:01,  4.69it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.77it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.47it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 260, in render_func
#     return render_multiview(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 223, in render_multiview
#     outputs = renderer.render(pose, lightdir=compute_lightdir(pose), **renderer_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 191, in render
#     matte = raw_color if uv_map else render_matte(norms, raw_depth, faces, bcent) # use original depth for matte
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 170, in render_matte
#     verts_index = self.tmesh.faces[faces.reshape(-1)]    # (n, 3)
#                   ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# IndexError: index 8355821 is out of bounds for axis 0 with size 272
#
# ✅ dbb84e2ad5684e5c994abc35773f3bf8 done
# ✅ 5ca6b82e6a104e71936ff1dff91646f8 done
# ✅ bf3939215c0b4ef79074788d878f0217 done
# ❌ c7e68786d06044839dda5509990390b3 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/c7e68786d06044839dda5509990390b3/c7e68786d06044839dda5509990390b3.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/c7e68786d06044839dda5509990390b3
#
# INFO | Segmenting mesh c7e68786d06044839dda5509990390b3.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.39it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.67it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:01,  4.78it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.85it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.88it/s]
# Rendering Multiviews...:  50%|█████     | 6/12 [00:01<00:01,  4.35it/s]
# Rendering Multiviews...:  58%|█████▊    | 7/12 [00:01<00:01,  4.35it/s]
# Rendering Multiviews...:  67%|██████▋   | 8/12 [00:01<00:00,  4.33it/s]
# Rendering Multiviews...:  75%|███████▌  | 9/12 [00:02<00:00,  4.32it/s]
# Rendering Multiviews...:  83%|████████▎ | 10/12 [00:02<00:00,  4.32it/s]
# Rendering Multiviews...:  92%|█████████▏| 11/12 [00:02<00:00,  4.29it/s]
# Rendering Multiviews...: 100%|██████████| 12/12 [00:02<00:00,  4.31it/s]
# Rendering Multiviews...: 100%|██████████| 12/12 [00:02<00:00,  4.42it/s]
#
# Computing SAM Masks for norms: 0it [00:00, ?it/s]INFO | For numpy array image, we assume (HxWxC) format
# INFO | Computing image embeddings for the provided image...
# INFO | Image embeddings computed.
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory efficient kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:607.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Memory Efficient attention has been runtime disabled. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:495.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Flash attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:609.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: Expected query, key and value to all be of dtype: {Half, BFloat16}. Got Query dtype: float, Key dtype: float, and Value dtype: float instead. (Triggered internally at ../aten/src/ATen/native/transformers/sdp_utils_cpp.h:98.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: CuDNN attention kernel not used because: (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:611.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/ys/mesh_reasoning/samesh/third_party/segment-anything-2/sam2/modeling/sam/transformer.py:270: UserWarning: The CuDNN backend needs to be enabled by setting the enviornment variable`TORCH_CUDNN_SDPA_ENABLED=1` (Triggered internally at ../aten/src/ATen/native/transformers/cuda/sdp_utils.cpp:409.)
#   out = F.scaled_dot_product_attention(q, k, v, dropout_p=dropout_p)
# /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py:1541: UserWarning: Flash Attention kernel failed due to: No available kernel. Aborting execution.
# Falling back to all available kernels for scaled_dot_product_attention (which may have a slower speed).
#   return forward_call(*args, **kwargs)
#
# Computing SAM Masks for norms: 1it [00:01,  1.80s/it]INFO | For numpy array image, we assume (HxWxC) format
# INFO | Computing image embeddings for the provided image...
# INFO | Image embeddings computed.
#
# Computing SAM Masks for norms: 2it [00:03,  1.56s/it]
# Computing SAM Masks for norms: 2it [00:03,  1.60s/it]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 293, in render
#     call_sam(image, faces != -1) for image, faces in \
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 285, in call_sam
#     [point_grid_from_mask(mask, self.config.sam.sam.engine_config.points_per_side ** 2)]
#      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam.py", line 105, in point_grid_from_mask
#     raise ValueError('No valid points in mask')
# ValueError: No valid points in mask
#
# ✅ 5501bccddeea4938b4386d8a1a7b8233 done
# ✅ 049a1db6b9bb498d8d74370be258e0b6 done
# ✅ 6012754b54094907a324be68c42eb72b done
# ✅ 2d0c7cd37c10495a9309230f30614e9c done
# ✅ 010e59ac3bc14cfcac5056b42978c9e6 done
# ❌ 034ddb9bc4544023989f3433a613917c failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/034ddb9bc4544023989f3433a613917c/034ddb9bc4544023989f3433a613917c.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/034ddb9bc4544023989f3433a613917c
#
# INFO | Segmenting mesh 034ddb9bc4544023989f3433a613917c.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.64it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.18it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:02,  4.45it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.56it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.45it/s]
# Rendering Multiviews...:  42%|████▏     | 5/12 [00:01<00:01,  4.29it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 260, in render_func
#     return render_multiview(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 223, in render_multiview
#     outputs = renderer.render(pose, lightdir=compute_lightdir(pose), **renderer_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 191, in render
#     matte = raw_color if uv_map else render_matte(norms, raw_depth, faces, bcent) # use original depth for matte
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 170, in render_matte
#     verts_index = self.tmesh.faces[faces.reshape(-1)]    # (n, 3)
#                   ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# IndexError: index 311 is out of bounds for axis 0 with size 272
#
# ✅ 2a62fca27766483ea15ee651383c160a done
# ✅ 455399fb20eb432eb2750d63ca192fba done
# ✅ 006c3cf0236e413292d9c2180e1b60ba done
# ✅ b442e6fc171443138a919fdc90f24654 done
# ✅ 041ee3f9d8ce453dbdc1a696431041c6 done
# ✅ 0202ec72baf548bb957406ed2d88961d done
# ✅ efed5b6761fb4111b34deaac46029a15 done
# ✅ 34e59730f0f045da85f741a4094d4a02 done
# ✅ 2d29a4c48cbe49208363a5a9feeac77f done
# ✅ bed114f672804828af3ab7503729bcf6 done
# ✅ 957d9fece2ab47fda94f354e2ba176d4 done
# ✅ 941cca1afd3847669af2d93cede2f88f done
# ✅ 943fc1a46d8f44d4a6c6c157f8a9d81d done
# ✅ 01474f78a328473b8d99ded65effb2cc done
# ✅ b4fe8462219b46088f49cfd847fe78a9 done
# ✅ fa7b314669be4cbc9316beb05cc5ee24 done
# ✅ 765d8c4c14424f58b4f62a2777efd3ac done
# ✅ cadb71ae0bfa453a9e5b03f1368f7bfe done
# ✅ 6c6c7d6d8b044e12bfc844bf123c8f41 done
# ✅ b5096aed3cd6420cb5516962a113d981 done
# ✅ c9606d7c63e24fe2bf671cc9f2643dc8 done
# ❌ 775165a5e097493da55d81e1ce0d990a failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/775165a5e097493da55d81e1ce0d990a/775165a5e097493da55d81e1ce0d990a.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/775165a5e097493da55d81e1ce0d990a
#
# INFO | Segmenting mesh 775165a5e097493da55d81e1ce0d990a.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   8%|▊         | 1/12 [00:00<00:02,  4.23it/s]
# Rendering Multiviews...:  17%|█▋        | 2/12 [00:00<00:02,  4.32it/s]
# Rendering Multiviews...:  25%|██▌       | 3/12 [00:00<00:02,  4.36it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.57it/s]
# Rendering Multiviews...:  33%|███▎      | 4/12 [00:00<00:01,  4.31it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 260, in render_func
#     return render_multiview(
#            ^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 223, in render_multiview
#     outputs = renderer.render(pose, lightdir=compute_lightdir(pose), **renderer_args)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 191, in render
#     matte = raw_color if uv_map else render_matte(norms, raw_depth, faces, bcent) # use original depth for matte
#                                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/renderer/renderer.py", line 170, in render_matte
#     verts_index = self.tmesh.faces[faces.reshape(-1)]    # (n, 3)
#                   ~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
# IndexError: index 364 is out of bounds for axis 0 with size 352
#
# ✅ b2a1fad2c9b0411f85565d3bb1796a20 done
# ✅ 91bc888bf8d54da9bfceefccaac734b8 done
# ✅ 038108ec3b03444ebda00e7fc2611bdd done
# ❌ 8c4d1c02f0174ca6aec283ebbd7f881d failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
# Segmenting mesh with SAMesh:  ../assets/CustomDataset_Completed/000-000/8c4d1c02f0174ca6aec283ebbd7f881d/8c4d1c02f0174ca6aec283ebbd7f881d.obj
# [segment_mesh_ys] output: ../outputs/mesh_segmentation_output/CustomDataset/000-000/8c4d1c02f0174ca6aec283ebbd7f881d
#
# INFO | Segmenting mesh 8c4d1c02f0174ca6aec283ebbd7f881d.obj
# INFO | Loaded checkpoint sucessfully
#
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Rendering Multiviews...:   0%|          | 0/12 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 116, in _segment_mesh
#     segment_mesh_ys(str(src_obj), self.config, visualize=visualize)  # noqa: F405
#     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 706, in segment_mesh_ys
#     faces2label, _ = model(tmesh, visualize_path=visualize_path, target_labels=target_labels)
#                      ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1532, in _wrapped_call_impl
#     return self._call_impl(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/torch/nn/modules/module.py", line 1541, in _call_impl
#     return forward_call(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 617, in forward
#     renders = self.render(scene, visualize_path=visualize_path)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/src/samesh/models/sam_mesh.py", line 276, in render
#     renders = render_func()
#               ^^^^^^^^^^^^^
# ...
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh 0273352444e14e8ab4f484679ff21ebe.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/0273352444e14e8ab4f484679ff21ebe'
#
# ❌ aa6dea3384084a65986eda03c2cc11a7 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh aa6dea3384084a65986eda03c2cc11a7.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/aa6dea3384084a65986eda03c2cc11a7'
#
# ❌ 03f935f1c9174cfdbcc512db947395ec failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh 03f935f1c9174cfdbcc512db947395ec.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/03f935f1c9174cfdbcc512db947395ec'
#
# ❌ 9831b1d119a84e0f85e1901c3449a623 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh 9831b1d119a84e0f85e1901c3449a623.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/9831b1d119a84e0f85e1901c3449a623'
#
# ❌ 5bbff140704a4d0bbe06282e582ef04d failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh 5bbff140704a4d0bbe06282e582ef04d.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/5bbff140704a4d0bbe06282e582ef04d'
#
# ❌ 63969b6276b24b038dc0f89d03a4fdd0 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh 63969b6276b24b038dc0f89d03a4fdd0.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/63969b6276b24b038dc0f89d03a4fdd0'
#
# ❌ e030179d25844f4c897c2a653edfe784 failed
# Warning:
# Unable to load the following plugins:
#
# 	libio_e57.so: libio_e57.so does not seem to be a Qt Plugin.
#
# Cannot load library /home/user/anaconda3/envs/samesh/lib/python3.12/site-packages/pymeshlab/lib/plugins/libio_e57.so: (/lib/x86_64-linux-gnu/libp11-kit.so.0: undefined symbol: ffi_type_pointer, version LIBFFI_BASE_7.0)
#
# config: {'cache': '../outputs/mesh_segmentation_cache', 'cache_overwrite': False, 'output': '../outputs/mesh_segmentation_output/CustomDataset/000-000', 'sam': {'sam': {'checkpoint': '../third_party/segment-anything-2/checkpoints/sam2_hiera_large.pt', 'model_config': 'sam2_hiera_l.yaml', 'auto': True, 'ground': False, 'engine_config': {'points_per_side': 32, 'crop_n_layers': 0, 'pred_iou_thresh': 0.5, 'stability_score_thresh': 0.7, 'stability_score_offset': 1.0}}}, 'sam_mesh': {'use_modes': ['sdf', 'norms'], 'min_area': 1024, 'connections_bin_resolution': 100, 'connections_bin_threshold_percentage': 0.125, 'smoothing_threshold_percentage_size': 0.025, 'smoothing_threshold_percentage_area': 0.025, 'smoothing_iterations': 64, 'repartition_cost': 1, 'repartition_lambda': 6, 'repartition_iterations': 1}, 'renderer': {'target_dim': [1024, 1024], 'camera_generation_method': 'icosahedron', 'renderer_args': {'interpolate_norms': True}, 'sampling_args': {'radius': 2}, 'lighting_args': {}}}
# ../outputs/mesh_segmentation_output/CustomDataset/000-000
#
# INFO | Segmenting mesh e030179d25844f4c897c2a653edfe784.obj
# Traceback (most recent call last):
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 207, in <module>
#     main()
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 196, in main
#     pipeline.process(
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 80, in process
#     seg_glb = self._segment_mesh(mesh_id, visualize)
#               ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/home/user/ys/mesh_reasoning/samesh/notebooks/../src/ys/mesh_segmentation_pipeline.py", line 114, in _segment_mesh
#     target_dir.mkdir(parents=True, exist_ok=True)
#   File "/home/user/anaconda3/envs/samesh/lib/python3.12/pathlib.py", line 1311, in mkdir
#     os.mkdir(self, mode)
# OSError: [Errno 28] No space left on device: '../outputs/mesh_segmentation_output/CustomDataset/000-000/e030179d25844f4c897c2a653edfe784'
#
#
# ❌ batch exited with code None.
